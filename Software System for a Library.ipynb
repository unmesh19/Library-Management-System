# %%
import random
from datetime import date, timedelta
from abc import ABC, abstractmethod

# %%
class LibraryCard:
    def __init__(self, card_id, issue_date = date.today()):
        self.card_id = card_id
        self.issue_date = issue_date

    def get_card_info(self):
        return f"Card ID: {self.card_id}, Issued on: {self.issue_date}"

# %%
class Book:
    def __init__(self, title, author, isbn):
        self.title = title
        self.author = author
        self.isbn = isbn
        self.is_available = True

    def borrow(self):
        if self.is_available:
            self.is_available = False
            return True
        return False

    def return_book(self):
        self.is_available = True

# %%
class LibraryMember(ABC):
    def __init__(self, name, member_id, borrowing_limit):
        self.name =  name
        self.__member_id = member_id
        self.library_card = LibraryCard(member_id)
        self.borrowing_limit = borrowing_limit
        self.borrowed_books = []

    def get_member_id(self):
        return self.__member_id
        
    @abstractmethod
    def display_info(self):
        pass

    def borrow_book(self, book):
        if len(self.borrowed_books) >= self.borrowing_limit:
            return f"{self.name} has reached the borrowing limit."

        if not book.borrow():
            return f"The book '{book.title}' is currently unavailable."

        due_date = date.today() + timedelta(days=14)
        self.borrowed_books.append((book, due_date))
        
        return f"{self.name} borrowed '{book.title}' due by {due_date}"

# %%
class Library:
    def __init__(self):
        self.books = []

    def search_books(self, title=None, author=None, isbn=None):
        results = [book for book in self.books if 
                   (title is None or book.title == title) and
                   (author is None or book.author == author) and
                   (isbn is None or book.isbn == isbn)]
        return results

# %%
class StudentMember(LibraryMember):
    def __init__(self, name, member_id, student_class):
        super().__init__(name, member_id, borrowing_limit=2)
        self.student_class = student_class

    def display_info(self):
        return f"{self.name} is a student in {self.student_class} with member ID {self.get_member_id()}"

# %%
class FacultyMember(LibraryMember):
    def __init__(self, name, member_id, department):
        super().__init__(name, member_id, borrowing_limit=5)
        self.department = department

    def display_info(self):
        return f"{self.name} is faculty from the {self.department} department with member ID {self.get_member_id()}"

# %%
book_titles_authors = [
    ("To Kill a Mockingbird", "Harper Lee"),
    ("1984", "George Orwell"),
    ("Moby Dick", "Herman Melville"),
    ("Pride and Prejudice", "Jane Austen"),
    ("War and Peace", "Leo Tolstoy"),
    ("The Great Gatsby", "F. Scott Fitzgerald"),
    ("Crime and Punishment", "Fyodor Dostoevsky"),
    ("The Catcher in the Rye", "J.D. Salinger"),
    ("The Odyssey", "Homer"),
    ("Brave New World", "Aldous Huxley"),
    ("The Lord of the Rings", "J.R.R. Tolkien"),
    ("Jane Eyre", "Charlotte Bronte"),
    ("The Divine Comedy", "Dante Alighieri"),
    ("Harry Potter and the Philosopher's Stone", "J.K. Rowling"),
    ("The Hobbit", "J.R.R. Tolkien"),
    ("Animal Farm", "George Orwell"),
    ("The Little Prince", "Antoine de Saint-Exupéry"),
    ("The Adventures of Huckleberry Finn", "Mark Twain"),
    ("Fahrenheit 451", "Ray Bradbury"),
    ("Don Quixote", "Miguel de Cervantes"),
    ("Wuthering Heights", "Emily Bronte"),
    ("The Scarlet Letter", "Nathaniel Hawthorne"),
    ("A Tale of Two Cities", "Charles Dickens"),
    ("Great Expectations", "Charles Dickens"),
    ("Les Miserables", "Victor Hugo"),
    ("Dracula", "Bram Stoker"),
    ("The Picture of Dorian Gray", "Oscar Wilde"),
    ("The Brothers Karamazov", "Fyodor Dostoevsky"),
    ("The Grapes of Wrath", "John Steinbeck"),
    ("Alice's Adventures in Wonderland", "Lewis Carroll"),
    ("Anna Karenina", "Leo Tolstoy"),
    ("Ulysses", "James Joyce"),
    ("Gone with the Wind", "Margaret Mitchell"),
    ("Catch-22", "Joseph Heller"),
    ("Lolita", "Vladimir Nabokov"),
    ("One Hundred Years of Solitude", "Gabriel Garcia Marquez"),
    ("Rebecca", "Daphne du Maurier"),
    ("The Stranger", "Albert Camus"),
    ("The Count of Monte Cristo", "Alexandre Dumas"),
    ("Sense and Sensibility", "Jane Austen"),
    ("Frankenstein", "Mary Shelley"),
    ("Of Mice and Men", "John Steinbeck"),
    ("The Sun Also Rises", "Ernest Hemingway"),
    ("A Farewell to Arms", "Ernest Hemingway"),
    ("Slaughterhouse-Five", "Kurt Vonnegut"),
    ("Lord of the Flies", "William Golding"),
    ("The Sound and the Fury", "William Faulkner"),
    ("East of Eden", "John Steinbeck"),
    ("The Bell Jar", "Sylvia Plath"),
    ("Beloved", "Toni Morrison"),
    ("The Old Man and the Sea", "Ernest Hemingway"),
    ("The Road", "Cormac McCarthy"),
    ("Invisible Man", "Ralph Ellison"),
    ("White Teeth", "Zadie Smith"),
    ("Midnight's Children", "Salman Rushdie"),
    ("The Kite Runner", "Khaled Hosseini"),
    ("Life of Pi", "Yann Martel"),
    ("The Book Thief", "Markus Zusak"),
    ("Memoirs of a Geisha", "Arthur Golden"),
    ("Shogun", "James Clavell"),
    ("The Shining", "Stephen King"),
    ("The Handmaid's Tale", "Margaret Atwood"),
    ("Dune", "Frank Herbert"),
    ("The Alchemist", "Paulo Coelho"),
    ("Good Omens", "Neil Gaiman and Terry Pratchett"),
    ("The Secret History", "Donna Tartt"),
    ("The Poisonwood Bible", "Barbara Kingsolver"),
    ("Outlander", "Diana Gabaldon"),
    ("Pillars of the Earth", "Ken Follett"),
    ("American Gods", "Neil Gaiman"),
    ("The Name of the Rose", "Umberto Eco"),
    ("Jurassic Park", "Michael Crichton"),
    ("Ender's Game", "Orson Scott Card"),
    ("The Giver", "Lois Lowry"),
    ("The Lovely Bones", "Alice Sebold"),
    ("The Road to Serfdom", "Friedrich Hayek"),
    ("The Hitchhiker's Guide to the Galaxy", "Douglas Adams"),
    ("Norwegian Wood", "Haruki Murakami"),
    ("The Time Traveler's Wife", "Audrey Niffenegger"),
    ("The Hunger Games", "Suzanne Collins"),
    ("Cloud Atlas", "David Mitchell"),
    ("The Goldfinch", "Donna Tartt"),
    ("The Girl with the Dragon Tattoo", "Stieg Larsson"),
    ("Water for Elephants", "Sara Gruen"),
    ("The Shadow of the Wind", "Carlos Ruiz Zafón"),
    ("The Road", "Cormac McCarthy"),
    ("The Secret Life of Bees", "Sue Monk Kidd"),
    ("A Prayer for Owen Meany", "John Irving"),
    ("The Joy Luck Club", "Amy Tan"),
    ("The Shipping News", "Annie Proulx"),
    ("The Glass Castle", "Jeannette Walls"),
    ("Big Little Lies", "Liane Moriarty"),
    ("The Light We Lost", "Jill Santopolo"),
    ("Sharp Objects", "Gillian Flynn"),
    ("The Da Vinci Code", "Dan Brown"),
    ("The Night Circus", "Erin Morgenstern"),
    ("A Man Called Ove", "Fredrik Backman"),
    ("Normal People", "Sally Rooney"),
    ("Little Fires Everywhere", "Celeste Ng"),
    ("Where the Crawdads Sing", "Delia Owens")
]

# %%
books = [Book(title, author, f"ISBN-{1000+i}") for i, (title, author) in enumerate(book_titles_authors)]

# %%
library = Library()
library.books = books

# %%
student_names = [
    "Alice Johnson", "Bob Smith", "Catherine Lee", "David Brown", "Evelyn Garcia",
    "Frank Miller", "Grace Wilson", "Henry Moore", "Isabella Taylor", "Jack White",
    "Karen Thomas", "Larry Harris", "Megan Martin", "Nathan Lewis", "Olivia Walker",
    "Paul Hall", "Quincy Allen", "Rachel Young", "Samuel King", "Tina Scott",
    "Uma Adams", "Victor Green", "Wendy Baker", "Xavier Nelson", "Yara Carter",
    "Zachary Mitchell", "Amanda Perez", "Bryan Reed", "Chloe Phillips", "Dylan Evans"
]

# %%
faculty_names = [
    "Dr. Emily Cooper", "Dr. Michael Clark", "Prof. Sarah Martinez", "Prof. John Thompson",
    "Dr. Laura Peterson", "Prof. James Anderson", "Dr. Mary Jackson", "Dr. Robert Turner",
    "Prof. Linda Lee", "Dr. Thomas Walker"
]

# %%
departments = ["Physics", "Mathematics", "Statistics", "Biotech", "Chemistry"]
student_classes = ["10th Grade", "11th Grade", "12th Grade"]

# %%
students = [
    StudentMember(name, f"S{i+1:03d}", student_classes[i // 10])
    for i, name in enumerate(student_names)
]

# %%
faculty_members = [
    FacultyMember(name, f"F{i+1:03d}", departments[i % len(departments)])
    for i, name in enumerate(faculty_names)
]

# %%
def borrow_books_for_member(member, num_books):
    borrowed_books = []
    for _ in range(num_books):
        available_books = [book for book in library.books if book.is_available]
        if not available_books:
            print(f"No more available books for {member.name}.")
            break
        
        book = random.choice(available_books)
        result = member.borrow_book(book)
        borrowed_books.append(result)
    return borrowed_books

# %%
all_members = students + faculty_members
random.shuffle(all_members)

borrow_limits = {StudentMember: 2, FacultyMember: 5}

# %%
def borrow_books_for_all_members(members):
    for member in members:
        borrow_limit = borrow_limits[type(member)]
        borrow_books_for_member(member, borrow_limit)

# %%
borrow_books_for_all_members(all_members)
# Out:
# No more available books for Prof. Sarah Martinez.
# No more available books for Tina Scott.
# No more available books for Grace Wilson.
# No more available books for Chloe Phillips.

# %%
for member in all_members:
    print(f"\n{member.display_info()}")
    for book, due_date in member.borrowed_books:
        print(f"  Borrowed '{book.title}' by {book.author}, Due on: {due_date}")
# Out:
# Dr. Laura Peterson is faculty from the Chemistry department with member ID F005
#   Borrowed 'The Hobbit' by J.R.R. Tolkien, Due on: 2024-11-13
#   Borrowed 'The Poisonwood Bible' by Barbara Kingsolver, Due on: 2024-11-13
#   Borrowed 'The Light We Lost' by Jill Santopolo, Due on: 2024-11-13
#   Borrowed 'The Grapes of Wrath' by John Steinbeck, Due on: 2024-11-13
#   Borrowed 'White Teeth' by Zadie Smith, Due on: 2024-11-13
#
# Paul Hall is a student in 11th Grade with member ID S016
#   Borrowed 'Water for Elephants' by Sara Gruen, Due on: 2024-11-13
#   Borrowed 'Beloved' by Toni Morrison, Due on: 2024-11-13
#
# David Brown is a student in 10th Grade with member ID S004
#   Borrowed 'One Hundred Years of Solitude' by Gabriel Garcia Marquez, Due on: 2024-11-13
#   Borrowed 'The Night Circus' by Erin Morgenstern, Due on: 2024-11-13
#
# Bryan Reed is a student in 12th Grade with member ID S028
#   Borrowed 'To Kill a Mockingbird' by Harper Lee, Due on: 2024-11-13
#   Borrowed 'The Secret Life of Bees' by Sue Monk Kidd, Due on: 2024-11-13
#
# Alice Johnson is a student in 10th Grade with member ID S001
#   Borrowed 'Fahrenheit 451' by Ray Bradbury, Due on: 2024-11-13
#   Borrowed 'Normal People' by Sally Rooney, Due on: 2024-11-13
#
# Karen Thomas is a student in 11th Grade with member ID S011
#   Borrowed 'Where the Crawdads Sing' by Delia Owens, Due on: 2024-11-13
#   Borrowed 'The Alchemist' by Paulo Coelho, Due on: 2024-11-13
#
# Henry Moore is a student in 10th Grade with member ID S008
#   Borrowed 'The Lord of the Rings' by J.R.R. Tolkien, Due on: 2024-11-13
#   Borrowed 'Jurassic Park' by Michael Crichton, Due on: 2024-11-13
#
# Wendy Baker is a student in 12th Grade with member ID S023
#   Borrowed 'The Girl with the Dragon Tattoo' by Stieg Larsson, Due on: 2024-11-13
#   Borrowed 'The Handmaid's Tale' by Margaret Atwood, Due on: 2024-11-13
#
# Dr. Thomas Walker is faculty from the Chemistry department with member ID F010
#   Borrowed 'The Odyssey' by Homer, Due on: 2024-11-13
#   Borrowed 'American Gods' by Neil Gaiman, Due on: 2024-11-13
#   Borrowed 'War and Peace' by Leo Tolstoy, Due on: 2024-11-13
#   Borrowed 'The Adventures of Huckleberry Finn' by Mark Twain, Due on: 2024-11-13
#   Borrowed 'Lord of the Flies' by William Golding, Due on: 2024-11-13
#
# Evelyn Garcia is a student in 10th Grade with member ID S005
#   Borrowed 'Shogun' by James Clavell, Due on: 2024-11-13
#   Borrowed 'Les Miserables' by Victor Hugo, Due on: 2024-11-13
#
# Dr. Michael Clark is faculty from the Mathematics department with member ID F002
#   Borrowed 'The Glass Castle' by Jeannette Walls, Due on: 2024-11-13
#   Borrowed 'Ulysses' by James Joyce, Due on: 2024-11-13
#   Borrowed 'The Scarlet Letter' by Nathaniel Hawthorne, Due on: 2024-11-13
#   Borrowed 'East of Eden' by John Steinbeck, Due on: 2024-11-13
#   Borrowed 'The Name of the Rose' by Umberto Eco, Due on: 2024-11-13
#
# Jack White is a student in 10th Grade with member ID S010
#   Borrowed 'The Brothers Karamazov' by Fyodor Dostoevsky, Due on: 2024-11-13
#   Borrowed 'Alice's Adventures in Wonderland' by Lewis Carroll, Due on: 2024-11-13
#
# Dylan Evans is a student in 12th Grade with member ID S030
#   Borrowed 'The Old Man and the Sea' by Ernest Hemingway, Due on: 2024-11-13
#   Borrowed 'The Count of Monte Cristo' by Alexandre Dumas, Due on: 2024-11-13
#
# Zachary Mitchell is a student in 12th Grade with member ID S026
#   Borrowed 'Frankenstein' by Mary Shelley, Due on: 2024-11-13
#   Borrowed 'The Shining' by Stephen King, Due on: 2024-11-13
#
# Prof. James Anderson is faculty from the Physics department with member ID F006
#   Borrowed 'A Tale of Two Cities' by Charles Dickens, Due on: 2024-11-13
#   Borrowed 'Little Fires Everywhere' by Celeste Ng, Due on: 2024-11-13
#   Borrowed 'Midnight's Children' by Salman Rushdie, Due on: 2024-11-13
#   Borrowed 'The Sound and the Fury' by William Faulkner, Due on: 2024-11-13
#   Borrowed 'Don Quixote' by Miguel de Cervantes, Due on: 2024-11-13
#
# Dr. Emily Cooper is faculty from the Physics department with member ID F001
#   Borrowed 'Rebecca' by Daphne du Maurier, Due on: 2024-11-13
#   Borrowed 'Norwegian Wood' by Haruki Murakami, Due on: 2024-11-13
#   Borrowed 'Moby Dick' by Herman Melville, Due on: 2024-11-13
#   Borrowed 'A Man Called Ove' by Fredrik Backman, Due on: 2024-11-13
#   Borrowed 'The Book Thief' by Markus Zusak, Due on: 2024-11-13
#
# Prof. John Thompson is faculty from the Biotech department with member ID F004
#   Borrowed 'The Hunger Games' by Suzanne Collins, Due on: 2024-11-13
#   Borrowed 'Lolita' by Vladimir Nabokov, Due on: 2024-11-13
#   Borrowed 'The Little Prince' by Antoine de Saint-Exupéry, Due on: 2024-11-13
#   Borrowed 'Catch-22' by Joseph Heller, Due on: 2024-11-13
#   Borrowed 'Slaughterhouse-Five' by Kurt Vonnegut, Due on: 2024-11-13
#
# Dr. Mary Jackson is faculty from the Mathematics department with member ID F007
#   Borrowed 'The Great Gatsby' by F. Scott Fitzgerald, Due on: 2024-11-13
#   Borrowed 'The Divine Comedy' by Dante Alighieri, Due on: 2024-11-13
#   Borrowed 'Pride and Prejudice' by Jane Austen, Due on: 2024-11-13
#   Borrowed 'Ender's Game' by Orson Scott Card, Due on: 2024-11-13
#   Borrowed 'Invisible Man' by Ralph Ellison, Due on: 2024-11-13
#
# Isabella Taylor is a student in 10th Grade with member ID S009
#   Borrowed 'The Catcher in the Rye' by J.D. Salinger, Due on: 2024-11-13
#   Borrowed 'A Farewell to Arms' by Ernest Hemingway, Due on: 2024-11-13
#
# Larry Harris is a student in 11th Grade with member ID S012
#   Borrowed 'The Shipping News' by Annie Proulx, Due on: 2024-11-13
#   Borrowed 'Anna Karenina' by Leo Tolstoy, Due on: 2024-11-13
#
# Xavier Nelson is a student in 12th Grade with member ID S024
#   Borrowed 'Cloud Atlas' by David Mitchell, Due on: 2024-11-13
#   Borrowed 'Wuthering Heights' by Emily Bronte, Due on: 2024-11-13
#
# Amanda Perez is a student in 12th Grade with member ID S027
#   Borrowed 'The Goldfinch' by Donna Tartt, Due on: 2024-11-13
#   Borrowed '1984' by George Orwell, Due on: 2024-11-13
#
# Prof. Linda Lee is faculty from the Biotech department with member ID F009
#   Borrowed 'The Lovely Bones' by Alice Sebold, Due on: 2024-11-13
#   Borrowed 'Harry Potter and the Philosopher's Stone' by J.K. Rowling, Due on: 2024-11-13
#   Borrowed 'Crime and Punishment' by Fyodor Dostoevsky, Due on: 2024-11-13
#   Borrowed 'Big Little Lies' by Liane Moriarty, Due on: 2024-11-13
#   Borrowed 'Gone with the Wind' by Margaret Mitchell, Due on: 2024-11-13
#
# Dr. Robert Turner is faculty from the Statistics department with member ID F008
#   Borrowed 'Pillars of the Earth' by Ken Follett, Due on: 2024-11-13
#   Borrowed 'The Road' by Cormac McCarthy, Due on: 2024-11-13
#   Borrowed 'Sharp Objects' by Gillian Flynn, Due on: 2024-11-13
#   Borrowed 'The Road to Serfdom' by Friedrich Hayek, Due on: 2024-11-13
#   Borrowed 'Life of Pi' by Yann Martel, Due on: 2024-11-13
#
# Bob Smith is a student in 10th Grade with member ID S002
#   Borrowed 'Dracula' by Bram Stoker, Due on: 2024-11-13
#   Borrowed 'Brave New World' by Aldous Huxley, Due on: 2024-11-13
#
# Quincy Allen is a student in 11th Grade with member ID S017
#   Borrowed 'Dune' by Frank Herbert, Due on: 2024-11-13
#   Borrowed 'Sense and Sensibility' by Jane Austen, Due on: 2024-11-13
#
# Frank Miller is a student in 10th Grade with member ID S006
#   Borrowed 'Great Expectations' by Charles Dickens, Due on: 2024-11-13
#   Borrowed 'Of Mice and Men' by John Steinbeck, Due on: 2024-11-13
#
# Rachel Young is a student in 11th Grade with member ID S018
#   Borrowed 'Memoirs of a Geisha' by Arthur Golden, Due on: 2024-11-13
#   Borrowed 'A Prayer for Owen Meany' by John Irving, Due on: 2024-11-13
#
# Uma Adams is a student in 12th Grade with member ID S021
#   Borrowed 'Outlander' by Diana Gabaldon, Due on: 2024-11-13
#   Borrowed 'The Da Vinci Code' by Dan Brown, Due on: 2024-11-13
#
# Megan Martin is a student in 11th Grade with member ID S013
#   Borrowed 'The Time Traveler's Wife' by Audrey Niffenegger, Due on: 2024-11-13
#   Borrowed 'The Sun Also Rises' by Ernest Hemingway, Due on: 2024-11-13
#
# Olivia Walker is a student in 11th Grade with member ID S015
#   Borrowed 'Jane Eyre' by Charlotte Bronte, Due on: 2024-11-13
#   Borrowed 'The Hitchhiker's Guide to the Galaxy' by Douglas Adams, Due on: 2024-11-13
#
# Victor Green is a student in 12th Grade with member ID S022
#   Borrowed 'The Giver' by Lois Lowry, Due on: 2024-11-13
#   Borrowed 'The Shadow of the Wind' by Carlos Ruiz Zafón, Due on: 2024-11-13
#
# Yara Carter is a student in 12th Grade with member ID S025
#   Borrowed 'Good Omens' by Neil Gaiman and Terry Pratchett, Due on: 2024-11-13
#   Borrowed 'The Road' by Cormac McCarthy, Due on: 2024-11-13
#
# Nathan Lewis is a student in 11th Grade with member ID S014
#   Borrowed 'The Secret History' by Donna Tartt, Due on: 2024-11-13
#   Borrowed 'The Kite Runner' by Khaled Hosseini, Due on: 2024-11-13
#
# Catherine Lee is a student in 10th Grade with member ID S003
#   Borrowed 'The Bell Jar' by Sylvia Plath, Due on: 2024-11-13
#   Borrowed 'The Stranger' by Albert Camus, Due on: 2024-11-13
#
# Samuel King is a student in 11th Grade with member ID S019
#   Borrowed 'The Joy Luck Club' by Amy Tan, Due on: 2024-11-13
#   Borrowed 'The Picture of Dorian Gray' by Oscar Wilde, Due on: 2024-11-13
#
# Prof. Sarah Martinez is faculty from the Statistics department with member ID F003
#   Borrowed 'Animal Farm' by George Orwell, Due on: 2024-11-13
#
# Tina Scott is a student in 11th Grade with member ID S020
#
# Grace Wilson is a student in 10th Grade with member ID S007
#
# Chloe Phillips is a student in 12th Grade with member ID S029
